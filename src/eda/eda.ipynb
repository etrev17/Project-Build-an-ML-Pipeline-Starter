# %%
# !pip install wandb==0.16.0
# !pip install ydata-profiling==4.12.1
# !pip install pandas==2.1.3
# Out:
# Collecting wandb==0.16.0
#   Downloading wandb-0.16.0-py3-none-any.whl (2.1 MB)
#      |████████████████████████████████| 2.1 MB 2.8 MB/s eta 0:00:01
# Requirement already satisfied: protobuf!=4.21.0,<5,>=3.15.0 in /root/miniconda3/envs/nyc_airbnb_dev/lib/python3.9/site-packages (from wandb==0.16.0) (3.20.3)
# Requirement already satisfied: PyYAML in /root/miniconda3/envs/nyc_airbnb_dev/lib/python3.9/site-packages (from wandb==0.16.0) (6.0.2)
# Requirement already satisfied: psutil>=5.0.0 in /root/miniconda3/envs/nyc_airbnb_dev/lib/python3.9/site-packages (from wandb==0.16.0) (6.1.1)
# Requirement already satisfied: Click!=8.0.0,>=7.1 in /root/miniconda3/envs/nyc_airbnb_dev/lib/python3.9/site-packages (from wandb==0.16.0) (8.1.8)
# Requirement already satisfied: typing-extensions in /root/miniconda3/envs/nyc_airbnb_dev/lib/python3.9/site-packages (from wandb==0.16.0) (4.12.2)
# Requirement already satisfied: GitPython!=3.1.29,>=1.0.0 in /root/miniconda3/envs/nyc_airbnb_dev/lib/python3.9/site-packages (from wandb==0.16.0) (3.1.43)
# Requirement already satisfied: docker-pycreds>=0.4.0 in /root/miniconda3/envs/nyc_airbnb_dev/lib/python3.9/site-packages (from wandb==0.16.0) (0.4.0)
# Requirement already satisfied: setuptools in /root/miniconda3/envs/nyc_airbnb_dev/lib/python3.9/site-packages (from wandb==0.16.0) (59.8.0)
# Requirement already satisfied: sentry-sdk>=1.0.0 in /root/miniconda3/envs/nyc_airbnb_dev/lib/python3.9/site-packages (from wandb==0.16.0) (2.19.2)
# Requirement already satisfied: requests<3,>=2.0.0 in /root/miniconda3/envs/nyc_airbnb_dev/lib/python3.9/site-packages (from wandb==0.16.0) (2.32.3)
# Collecting appdirs>=1.4.3
#   Downloading appdirs-1.4.4-py2.py3-none-any.whl (9.6 kB)
# Requirement already satisfied: six>=1.4.0 in /root/miniconda3/envs/nyc_airbnb_dev/lib/python3.9/site-packages (from docker-pycreds>=0.4.0->wandb==0.16.0) (1.17.0)
# Requirement already satisfied: gitdb<5,>=4.0.1 in /root/miniconda3/envs/nyc_airbnb_dev/lib/python3.9/site-packages (from GitPython!=3.1.29,>=1.0.0->wandb==0.16.0) (4.0.11)
# Requirement already satisfied: smmap<6,>=3.0.1 in /root/miniconda3/envs/nyc_airbnb_dev/lib/python3.9/site-packages (from gitdb<5,>=4.0.1->GitPython!=3.1.29,>=1.0.0->wandb==0.16.0) (5.0.0)
# Requirement already satisfied: certifi>=2017.4.17 in /root/miniconda3/envs/nyc_airbnb_dev/lib/python3.9/site-packages (from requests<3,>=2.0.0->wandb==0.16.0) (2024.12.14)
# Requirement already satisfied: idna<4,>=2.5 in /root/miniconda3/envs/nyc_airbnb_dev/lib/python3.9/site-packages (from requests<3,>=2.0.0->wandb==0.16.0) (3.10)
# Requirement already satisfied: charset_normalizer<4,>=2 in /root/miniconda3/envs/nyc_airbnb_dev/lib/python3.9/site-packages (from requests<3,>=2.0.0->wandb==0.16.0) (3.4.0)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /root/miniconda3/envs/nyc_airbnb_dev/lib/python3.9/site-packages (from requests<3,>=2.0.0->wandb==0.16.0) (1.26.19)
# Collecting setproctitle
#   Downloading setproctitle-1.3.4-cp39-cp39-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (30 kB)
# Installing collected packages: setproctitle, appdirs, wandb
#   Attempting uninstall: wandb
#     Found existing installation: wandb 0.10.31
#     Uninstalling wandb-0.10.31:
#       Successfully uninstalled wandb-0.10.31
# Successfully installed appdirs-1.4.4 setproctitle-1.3.4 wandb-0.16.0
# Collecting ydata-profiling==4.12.1
#   Downloading ydata_profiling-4.12.1-py2.py3-none-any.whl (390 kB)
#      |████████████████████████████████| 390 kB 3.0 MB/s eta 0:00:01
# Requirement already satisfied: scipy<1.14,>=1.4.1 in /root/miniconda3/envs/nyc_airbnb_dev/lib/python3.9/site-packages (from ydata-profiling==4.12.1) (1.13.1)
# Requirement already satisfied: jinja2<3.2,>=2.11.1 in /root/miniconda3/envs/nyc_airbnb_dev/lib/python3.9/site-packages (from ydata-profiling==4.12.1) (2.11.3)
# Requirement already satisfied: numpy<2.2,>=1.16.0 in /root/miniconda3/envs/nyc_airbnb_dev/lib/python3.9/site-packages (from ydata-profiling==4.12.1) (1.26.4)
# Requirement already satisfied: PyYAML<6.1,>=5.0.0 in /root/miniconda3/envs/nyc_airbnb_dev/lib/python3.9/site-packages (from ydata-profiling==4.12.1) (6.0.2)
# Requirement already satisfied: requests<3,>=2.24.0 in /root/miniconda3/envs/nyc_airbnb_dev/lib/python3.9/site-packages (from ydata-profiling==4.12.1) (2.32.3)
# Requirement already satisfied: pandas!=1.4.0,<3,>1.1 in /root/miniconda3/envs/nyc_airbnb_dev/lib/python3.9/site-packages (from ydata-profiling==4.12.1) (2.2.3)
# Collecting htmlmin==0.1.12
#   Downloading htmlmin-0.1.12.tar.gz (19 kB)
# Collecting imagehash==4.3.1
#   Downloading ImageHash-4.3.1-py2.py3-none-any.whl (296 kB)
#      |████████████████████████████████| 296 kB 24.7 MB/s eta 0:00:01
# Requirement already satisfied: pillow in /root/miniconda3/envs/nyc_airbnb_dev/lib/python3.9/site-packages (from imagehash==4.3.1->ydata-profiling==4.12.1) (9.4.0)
# Collecting dacite>=1.8
#   Downloading dacite-1.8.1-py3-none-any.whl (14 kB)
# Requirement already satisfied: MarkupSafe>=0.23 in /root/miniconda3/envs/nyc_airbnb_dev/lib/python3.9/site-packages (from jinja2<3.2,>=2.11.1->ydata-profiling==4.12.1) (1.1.1)
# Collecting matplotlib<3.10,>=3.5
#   Downloading matplotlib-3.9.4-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (8.3 MB)
#      |████████████████████████████████| 8.3 MB 19.5 MB/s eta 0:00:01
# Requirement already satisfied: kiwisolver>=1.3.1 in /root/miniconda3/envs/nyc_airbnb_dev/lib/python3.9/site-packages (from matplotlib<3.10,>=3.5->ydata-profiling==4.12.1) (1.4.7)
# Requirement already satisfied: cycler>=0.10 in /root/miniconda3/envs/nyc_airbnb_dev/lib/python3.9/site-packages (from matplotlib<3.10,>=3.5->ydata-profiling==4.12.1) (0.12.1)
# Requirement already satisfied: python-dateutil>=2.7 in /root/miniconda3/envs/nyc_airbnb_dev/lib/python3.9/site-packages (from matplotlib<3.10,>=3.5->ydata-profiling==4.12.1) (2.9.0.post0)
# Requirement already satisfied: pyparsing>=2.3.1 in /root/miniconda3/envs/nyc_airbnb_dev/lib/python3.9/site-packages (from matplotlib<3.10,>=3.5->ydata-profiling==4.12.1) (3.2.0)
# Requirement already satisfied: packaging>=20.0 in /root/miniconda3/envs/nyc_airbnb_dev/lib/python3.9/site-packages (from matplotlib<3.10,>=3.5->ydata-profiling==4.12.1) (24.2)
# Requirement already satisfied: importlib-resources>=3.2.0 in /root/miniconda3/envs/nyc_airbnb_dev/lib/python3.9/site-packages (from matplotlib<3.10,>=3.5->ydata-profiling==4.12.1) (6.4.5)
# Collecting contourpy>=1.0.1
#   Downloading contourpy-1.3.0-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (321 kB)
#      |████████████████████████████████| 321 kB 13.3 MB/s eta 0:00:01
# Collecting fonttools>=4.22.0
#   Downloading fonttools-4.55.3-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (4.6 MB)
#      |████████████████████████████████| 4.6 MB 23.5 MB/s eta 0:00:01     |█▏                              | 163 kB 23.5 MB/s eta 0:00:01     |█████████████████               | 2.5 MB 23.5 MB/s eta 0:00:01     |████████████████████████████▎   | 4.1 MB 23.5 MB/s eta 0:00:01
# Requirement already satisfied: zipp>=3.1.0 in /root/miniconda3/envs/nyc_airbnb_dev/lib/python3.9/site-packages (from importlib-resources>=3.2.0->matplotlib<3.10,>=3.5->ydata-profiling==4.12.1) (3.21.0)
# Collecting multimethod<2,>=1.4
#   Downloading multimethod-1.12-py3-none-any.whl (10 kB)
# Collecting numba<1,>=0.56.0
#   Downloading numba-0.60.0-cp39-cp39-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (3.7 MB)
#      |████████████████████████████████| 3.7 MB 15.5 MB/s eta 0:00:01
# Collecting llvmlite<0.44,>=0.43.0dev0
#   Downloading llvmlite-0.43.0-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (43.9 MB)
#      |████████████████████████████████| 43.9 MB 63 kB/s  eta 0:00:01     |███████████████████████████████▉| 43.7 MB 7.0 MB/s eta 0:00:01
# Requirement already satisfied: pytz>=2020.1 in /root/miniconda3/envs/nyc_airbnb_dev/lib/python3.9/site-packages (from pandas!=1.4.0,<3,>1.1->ydata-profiling==4.12.1) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /root/miniconda3/envs/nyc_airbnb_dev/lib/python3.9/site-packages (from pandas!=1.4.0,<3,>1.1->ydata-profiling==4.12.1) (2024.2)
# Collecting phik<0.13,>=0.11.1
#   Downloading phik-0.12.4-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (686 kB)
#      |████████████████████████████████| 686 kB 8.9 MB/s eta 0:00:01
# Requirement already satisfied: joblib>=0.14.1 in /root/miniconda3/envs/nyc_airbnb_dev/lib/python3.9/site-packages (from phik<0.13,>=0.11.1->ydata-profiling==4.12.1) (1.4.2)
# Collecting pydantic>=2
#   Downloading pydantic-2.10.4-py3-none-any.whl (431 kB)
#      |████████████████████████████████| 431 kB 9.7 MB/s eta 0:00:01
# Requirement already satisfied: typing-extensions>=4.12.2 in /root/miniconda3/envs/nyc_airbnb_dev/lib/python3.9/site-packages (from pydantic>=2->ydata-profiling==4.12.1) (4.12.2)
# Collecting pydantic-core==2.27.2
#   Downloading pydantic_core-2.27.2-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.0 MB)
#      |████████████████████████████████| 2.0 MB 13.8 MB/s eta 0:00:01
# Collecting annotated-types>=0.6.0
#   Downloading annotated_types-0.7.0-py3-none-any.whl (13 kB)
# Requirement already satisfied: six>=1.5 in /root/miniconda3/envs/nyc_airbnb_dev/lib/python3.9/site-packages (from python-dateutil>=2.7->matplotlib<3.10,>=3.5->ydata-profiling==4.12.1) (1.17.0)
# Requirement already satisfied: idna<4,>=2.5 in /root/miniconda3/envs/nyc_airbnb_dev/lib/python3.9/site-packages (from requests<3,>=2.24.0->ydata-profiling==4.12.1) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /root/miniconda3/envs/nyc_airbnb_dev/lib/python3.9/site-packages (from requests<3,>=2.24.0->ydata-profiling==4.12.1) (1.26.19)
# Requirement already satisfied: certifi>=2017.4.17 in /root/miniconda3/envs/nyc_airbnb_dev/lib/python3.9/site-packages (from requests<3,>=2.24.0->ydata-profiling==4.12.1) (2024.12.14)
# Requirement already satisfied: charset_normalizer<4,>=2 in /root/miniconda3/envs/nyc_airbnb_dev/lib/python3.9/site-packages (from requests<3,>=2.24.0->ydata-profiling==4.12.1) (3.4.0)
# Collecting seaborn<0.14,>=0.10.1
#   Downloading seaborn-0.13.2-py3-none-any.whl (294 kB)
#      |████████████████████████████████| 294 kB 20.9 MB/s eta 0:00:01
# Collecting statsmodels<1,>=0.13.2
#   Downloading statsmodels-0.14.4-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (10.8 MB)
#      |████████████████████████████████| 10.8 MB 5.3 MB/s eta 0:00:01
# Collecting patsy>=0.5.6
#   Downloading patsy-1.0.1-py2.py3-none-any.whl (232 kB)
#      |████████████████████████████████| 232 kB 4.4 MB/s eta 0:00:01
# Collecting tqdm<5,>=4.48.2
#   Downloading tqdm-4.67.1-py3-none-any.whl (78 kB)
#      |████████████████████████████████| 78 kB 3.1 MB/s eta 0:00:011
# Collecting typeguard<5,>=3
#   Downloading typeguard-4.4.1-py3-none-any.whl (35 kB)
# Requirement already satisfied: importlib-metadata>=3.6 in /root/miniconda3/envs/nyc_airbnb_dev/lib/python3.9/site-packages (from typeguard<5,>=3->ydata-profiling==4.12.1) (8.5.0)
# Collecting visions[type_image_path]<0.7.7,>=0.7.5
#   Downloading visions-0.7.6-py3-none-any.whl (104 kB)
#      |████████████████████████████████| 104 kB 4.9 MB/s eta 0:00:01
# Requirement already satisfied: attrs>=19.3.0 in /root/miniconda3/envs/nyc_airbnb_dev/lib/python3.9/site-packages (from visions[type_image_path]<0.7.7,>=0.7.5->ydata-profiling==4.12.1) (24.3.0)
# Collecting networkx>=2.4
#   Downloading networkx-3.2.1-py3-none-any.whl (1.6 MB)
#      |████████████████████████████████| 1.6 MB 4.4 MB/s eta 0:00:01
# Collecting wordcloud>=1.9.3
#   Downloading wordcloud-1.9.4-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (513 kB)
#      |████████████████████████████████| 513 kB 4.3 MB/s eta 0:00:01
# Collecting PyWavelets
#   Downloading pywavelets-1.6.0-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (4.5 MB)
#      |████████████████████████████████| 4.5 MB 4.6 MB/s eta 0:00:01
# Building wheels for collected packages: htmlmin
#   Building wheel for htmlmin (setup.py) ... done
#   Created wheel for htmlmin: filename=htmlmin-0.1.12-py3-none-any.whl size=27098 sha256=2877b80e4512f07678e85b08b33ee919fca3e0736e410dddf7bb438d1faae56c
#   Stored in directory: /root/.cache/pip/wheels/1d/05/04/c6d7d3b66539d9e659ac6dfe81e2d0fd4c1a8316cc5a403300
# Successfully built htmlmin
# Installing collected packages: PyWavelets, networkx, multimethod, fonttools, contourpy, visions, pydantic-core, patsy, matplotlib, llvmlite, imagehash, annotated-types, wordcloud, typeguard, tqdm, statsmodels, seaborn, pydantic, phik, numba, htmlmin, dacite, ydata-profiling
#   Attempting uninstall: matplotlib
#     Found existing installation: matplotlib 3.3.4
#     Uninstalling matplotlib-3.3.4:
#       Successfully uninstalled matplotlib-3.3.4
# Successfully installed PyWavelets-1.6.0 annotated-types-0.7.0 contourpy-1.3.0 dacite-1.8.1 fonttools-4.55.3 htmlmin-0.1.12 imagehash-4.3.1 llvmlite-0.43.0 matplotlib-3.9.4 multimethod-1.12 networkx-3.2.1 numba-0.60.0 patsy-1.0.1 phik-0.12.4 pydantic-2.10.4 pydantic-core-2.27.2 seaborn-0.13.2 statsmodels-0.14.4 tqdm-4.67.1 typeguard-4.4.1 visions-0.7.6 wordcloud-1.9.4 ydata-profiling-4.12.1
# Collecting pandas==2.1.3
#   Downloading pandas-2.1.3-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (12.3 MB)
#      |████████████████████████████████| 12.3 MB 6.2 MB/s eta 0:00:01    |████████████████████████▏       | 9.3 MB 6.2 MB/s eta 0:00:01     |██████████████████████████▏     | 10.1 MB 6.2 MB/s eta 0:00:01     |███████████████████████████▍    | 10.6 MB 6.2 MB/s eta 0:00:01     |████████████████████████████    | 10.8 MB 6.2 MB/s eta 0:00:01
# Requirement already satisfied: numpy<2,>=1.22.4 in /root/miniconda3/envs/nyc_airbnb_dev/lib/python3.9/site-packages (from pandas==2.1.3) (1.26.4)
# Requirement already satisfied: pytz>=2020.1 in /root/miniconda3/envs/nyc_airbnb_dev/lib/python3.9/site-packages (from pandas==2.1.3) (2024.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /root/miniconda3/envs/nyc_airbnb_dev/lib/python3.9/site-packages (from pandas==2.1.3) (2.9.0.post0)
# Requirement already satisfied: tzdata>=2022.1 in /root/miniconda3/envs/nyc_airbnb_dev/lib/python3.9/site-packages (from pandas==2.1.3) (2024.2)
# Requirement already satisfied: six>=1.5 in /root/miniconda3/envs/nyc_airbnb_dev/lib/python3.9/site-packages (from python-dateutil>=2.8.2->pandas==2.1.3) (1.17.0)
# Installing collected packages: pandas
#   Attempting uninstall: pandas
#     Found existing installation: pandas 2.2.3
#     Uninstalling pandas-2.2.3:
#       Successfully uninstalled pandas-2.2.3
# Successfully installed pandas-2.1.3

# %% [markdown]
# 1. Fetch the artifact we just created (sample.csv) from W&B and read it with pandas:

# %%
import wandb
import pandas as pd
# Note that we use save_code=True in the call to wandb.init so the notebook is uploaded and versioned by W&B
run = wandb.init(project="nyc_airbnb", group="eda", save_code=True)
local_path = wandb.use_artifact("sample.csv:latest").file()
df = pd.read_csv(local_path)
# Out:
# wandb: Currently logged in as: etrev17 (etrev17-western-governors-university). Use `wandb login --relogin` to force relogin
# wandb version 0.19.1 is available!  To upgrade, please run:
#  $ pip install wandb --upgrade
# Tracking run with wandb version 0.16.0
# Run data is saved locally in <code>/root/Project-Build-an-ML-Pipeline-Starter/src/eda/wandb/run-20250105_143713-uq0nvbai</code>
# Syncing run <strong><a href='https://wandb.ai/etrev17-western-governors-university/nyc_airbnb/runs/uq0nvbai' target="_blank">breezy-darkness-5</a></strong> to <a href='https://wandb.ai/etrev17-western-governors-university/nyc_airbnb' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/run' target="_blank">docs</a>)<br/>
#  View project at <a href='https://wandb.ai/etrev17-western-governors-university/nyc_airbnb' target="_blank">https://wandb.ai/etrev17-western-governors-university/nyc_airbnb</a>
#  View run at <a href='https://wandb.ai/etrev17-western-governors-university/nyc_airbnb/runs/uq0nvbai' target="_blank">https://wandb.ai/etrev17-western-governors-university/nyc_airbnb/runs/uq0nvbai</a>

# %% [markdown]
# 2. Explore the data in df

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20000 entries, 0 to 19999
# Data columns (total 16 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   id                              20000 non-null  int64
#  1   name                            19993 non-null  object
#  2   host_id                         20000 non-null  int64
#  3   host_name                       19992 non-null  object
#  4   neighbourhood_group             20000 non-null  object
#  5   neighbourhood                   20000 non-null  object
#  6   latitude                        20000 non-null  float64
#  7   longitude                       20000 non-null  float64
#  8   room_type                       20000 non-null  object
#  9   price                           20000 non-null  int64
#  10  minimum_nights                  20000 non-null  int64
#  11  number_of_reviews               20000 non-null  int64
#  12  last_review                     15877 non-null  object
#  13  reviews_per_month               15877 non-null  float64
#  14  calculated_host_listings_count  20000 non-null  int64
#  15  availability_365                20000 non-null  int64
# dtypes: float64(3), int64(7), object(6)
# memory usage: 2.4+ MB

# %%
df.describe()
# Out:
#                  id       host_id      latitude     longitude         price  \
# count  2.000000e+04  2.000000e+04  20000.000000  20000.000000  20000.000000
# mean   1.892380e+07  6.746034e+07     40.728455    -73.952125    153.269050
# std    1.101223e+07  7.857936e+07      0.054755      0.046559    243.325609
# min    2.539000e+03  2.571000e+03     40.508730    -74.239140      0.000000
# 25%    9.393540e+06  7.853718e+06     40.689420    -73.983030     69.000000
# 50%    1.952117e+07  3.111431e+07     40.722730    -73.955640    105.000000
# 75%    2.912936e+07  1.068426e+08     40.762990    -73.936380    175.000000
# max    3.648561e+07  2.742733e+08     40.913060    -73.717950  10000.000000
#
#        minimum_nights  number_of_reviews  reviews_per_month  \
# count    20000.000000       20000.000000       15877.000000
# mean         6.992100          23.274100           1.377446
# std         21.645449          44.927793           1.683006
# min          1.000000           0.000000           0.010000
# 25%          1.000000           1.000000           0.190000
# 50%          2.000000           5.000000           0.720000
# 75%          5.000000          23.000000           2.010000
# max       1250.000000         607.000000          27.950000
#
#        calculated_host_listings_count  availability_365
# count                    20000.000000      20000.000000
# mean                         6.955450        112.901200
# std                         32.433831        131.762226
# min                          1.000000          0.000000
# 25%                          1.000000          0.000000
# 50%                          1.000000         44.000000
# 75%                          2.000000        229.000000
# max                        327.000000        365.000000

# %%
df.head()
# Out:
#          id                                               name    host_id  \
# 0   9138664                Private Lg Room 15 min to Manhattan   47594947
# 1  31444015  TIME SQUARE CHARMING ONE BED IN HELL'S KITCHEN...    8523790
# 2   8741020  Voted #1 Location Quintessential 1BR W Village...   45854238
# 3  34602077  Spacious 1 bedroom apartment 15min from Manhattan  261055465
# 4  23203149   Big beautiful bedroom in huge Bushwick apartment     143460
#
#   host_name neighbourhood_group   neighbourhood  latitude  longitude  \
# 0      Iris              Queens       Sunnyside  40.74271  -73.92493
# 1    Johlex           Manhattan  Hell's Kitchen  40.76682  -73.98878
# 2      John           Manhattan    West Village  40.73631  -74.00611
# 3     Regan              Queens         Astoria  40.76424  -73.92351
# 4     Megan            Brooklyn        Bushwick  40.69839  -73.92044
#
#          room_type  price  minimum_nights  number_of_reviews last_review  \
# 0     Private room     74               2                  6  2019-05-26
# 1  Entire home/apt    170               3                  0         NaN
# 2  Entire home/apt    245               3                 51  2018-09-19
# 3  Entire home/apt    125               3                  1  2019-05-24
# 4     Private room     65               2                  8  2019-06-23
#
#    reviews_per_month  calculated_host_listings_count  availability_365
# 0               0.13                               1                 5
# 1                NaN                               1               188
# 2               1.12                               1                 0
# 3               0.65                               1                13
# 4               0.52                               2                 8

# %% [markdown]
# 3. What do you notice in the data? Look around and see what you can find.
#
# > For example, there are missing values in a few columns and the column `last_review` is a date but it is in string format. Look also at the `price` column, and note the outliers. There are some zeros and some very high prices. After talking to your stakeholders, you decide to consider from a minimum of `$10` to a maximum of `$350` per night.

# %% [markdown]
# 4. Fix some of the little problems we have found in the data with the following code:

# %%
# Drop outliers
min_price = 10
max_price = 350
idx = df['price'].between(min_price, max_price)
df = df[idx].copy()
# Convert last_review to datetime
df['last_review'] = pd.to_datetime(df['last_review'])

# %% [markdown]
# Note how we did not impute missing values. We will do that in the inference pipeline, so we will be able to handle missing values also in production.

# %% [markdown]
# 5. Check with df.info() that all obvious problems have been solved

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 10591 entries, 1 to 19999
# Data columns (total 16 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   id                              10591 non-null  int64
#  1   name                            10588 non-null  object
#  2   host_id                         10591 non-null  int64
#  3   host_name                       10585 non-null  object
#  4   neighbourhood_group             10591 non-null  object
#  5   neighbourhood                   10591 non-null  object
#  6   latitude                        10591 non-null  float64
#  7   longitude                       10591 non-null  float64
#  8   room_type                       10591 non-null  object
#  9   price                           10591 non-null  int64
#  10  minimum_nights                  10591 non-null  int64
#  11  number_of_reviews               10591 non-null  int64
#  12  last_review                     8293 non-null   datetime64[ns]
#  13  reviews_per_month               8293 non-null   float64
#  14  calculated_host_listings_count  10591 non-null  int64
#  15  availability_365                10591 non-null  int64
# dtypes: datetime64[ns](1), float64(3), int64(7), object(5)
# memory usage: 1.4+ MB

# %% [markdown]
# 6. Terminate the run by running `run.finish()`

# %%
run.finish()
# Out:
# VBox(children=(Label(value='0.043 MB of 0.043 MB uploaded\r'), FloatProgress(value=1.0, max=1.0)))
#  View run <strong style="color:#cdcd00">breezy-darkness-5</strong> at: <a href='https://wandb.ai/etrev17-western-governors-university/nyc_airbnb/runs/uq0nvbai' target="_blank">https://wandb.ai/etrev17-western-governors-university/nyc_airbnb/runs/uq0nvbai</a><br/> View job at <a href='https://wandb.ai/etrev17-western-governors-university/nyc_airbnb/jobs/QXJ0aWZhY3RDb2xsZWN0aW9uOjUyOTgyMjcwOQ==/version_details/v1' target="_blank">https://wandb.ai/etrev17-western-governors-university/nyc_airbnb/jobs/QXJ0aWZhY3RDb2xsZWN0aW9uOjUyOTgyMjcwOQ==/version_details/v1</a><br/>Synced 7 W&B file(s), 0 media file(s), 3 artifact file(s) and 2 other file(s)
# Find logs at: <code>./wandb/run-20250105_143713-uq0nvbai/logs</code>

# %% [markdown]
# 7. Save the notebook.

# %%
mlflow run . -P steps=download
# Out:
#   File "<ipython-input-9-977826255577>", line 1
#     mlflow run . -P steps=download
#            ^
# SyntaxError: invalid syntax
